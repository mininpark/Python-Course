# %%
# How to build a simple linear regression

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17488/1407044729.py in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn import linear_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Load dataset
data=pd.read_csv(r"C:\Users\admin\Desktop\Programming\CODE\Python\KocPythonFall2021\inclass\7GLMs\data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17488/1614557367.py in <module>
#       1 # Load dataset
# ----> 2 data=pd.read_csv(r"C:\Users\admin\Desktop\Programming\CODE\Python\KocPythonFall2021\inclass\7GLMs\data.csv")
#
# NameError: name 'pd' is not defined

# %%
# Quick [view about the dataset]
data
# Out:
#        ccode country              group name  numcode  year  groupcon  \
# 0          2     USA  AFRICAN-AMERICANS  BLA    201.0  1960       0.0
# 1          2     USA  AFRICAN-AMERICANS  BLA    201.0  1961       0.0
# 2          2     USA  AFRICAN-AMERICANS  BLA    201.0  1962       0.0
# 3          2     USA  AFRICAN-AMERICANS  BLA    201.0  1963       0.0
# 4          2     USA  AFRICAN-AMERICANS  BLA    201.0  1964       0.0
# ...      ...     ...                ...  ...      ...   ...       ...
# 16863    552     NaN                NaN  NaN      NaN  1960       NaN
# 16864    552     NaN                NaN  NaN      NaN  1961       NaN
# 16865    552     NaN                NaN  NaN      NaN  1962       NaN
# 16866    552     NaN                NaN  NaN      NaN  1963       NaN
# 16867    552     NaN                NaN  NaN      NaN  1964       NaN
#
#        aggdifxx  intercon  polity2     gdppc  country_pop  rebellion
# ...

# %%
data.shape
# Out:
# (16868, 13)

# %%
data.plot(kind='scatter', x='groupcon', y='gdppc')
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.plot(kind='box')
plt.show()

# %%
data.corr() #Correlation coefficients
# Out:
#                 ccode   numcode      year  groupcon  aggdifxx  intercon  \
# ccode        1.000000  1.000000  0.003201 -0.012763  0.035564  0.143819
# numcode      1.000000  1.000000  0.013463 -0.012739  0.035574  0.143812
# year         0.003201  0.013463  1.000000 -0.013204 -0.029495 -0.018861
# groupcon    -0.012763 -0.012739 -0.013204  1.000000 -0.177434 -0.161756
# aggdifxx     0.035564  0.035574 -0.029495 -0.177434  1.000000  0.121759
# intercon     0.143819  0.143812 -0.018861 -0.161756  0.121759  1.000000
# polity2     -0.277774 -0.245701  0.232761 -0.156593  0.086777  0.055340
# gdppc       -0.233185 -0.288873  0.249886 -0.221122 -0.009436 -0.037847
# country_pop  0.166254  0.199993  0.066376 -0.002322  0.121408  0.138917
# rebellion    0.254721  0.254721  0.028669  0.190123  0.040181  0.099526
#
#               polity2     gdppc  country_pop  rebellion
# ccode       -0.277774 -0.233185     0.166254   0.254721
# numcode     -0.245701 -0.288873     0.199993   0.254721
# ...

# %%
# change to dataframe variables
Country_code=pd.DataFrame(data['ccode'])

# %%
Country_code
# Out:
#        ccode
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 16863    552
# 16864    552
# 16865    552
# 16866    552
# 16867    552
#
# [16868 rows x 1 columns]

# %%
# build linear regression model
lm= linear_model.LinearRegression()
model =lm.fit(Country_code,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17488/104963626.py in <module>
#       1 # build linear regression model
# ----> 2 lm= linear_model.LinearRegression()
#       3 model =lm.fit(Country_code)
#
# NameError: name 'linear_model' is not defined
