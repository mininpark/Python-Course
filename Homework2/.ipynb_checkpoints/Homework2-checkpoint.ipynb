# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
from scipy import linalg, stats
# my regression model
from LinRegression import LinearRegressor

# %% [markdown]
# # Red Wine Quality Analysis

# %%
# Reading the dataset
# repository from UCI (https://archive.ics.uci.edu/ml/datasets/wine+quality)
data = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#for initial test
data.plot.scatter(x ='quality', y='residual sugar')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# # Gathering testing data

# %%
data.shape
# Out:
# (1599, 12)

# %%
data['quality'].unique
# Out:
# <bound method Series.unique of 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64>

# %%
data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
data['quality'].count()
# Out:
# 1599

# %%
# To check correlation
corrMatt=data.corr()
mask=np.array(corrMatt)
mask[np.tril_indices_from(mask)]=False
fig,ax=plt.subplots()
fig.set_size_inches(10,10)
sb.heatmap(corrMatt, mask=mask,vmax=.8, square=True,annot=True)
# Dark shades represents positive correlation while lighter shades represents negative correlation.
# If you set annot=True, you'll get values by which features are correlated to each other in grid-cells
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Initial Visual Analysis

# %%
for label in data.columns[:-1]:
# for label in ['alcohol']:
    plt.scatter(data['quality'], data[label])
    plt.title(label)
    plt.xlabel('quality')
    plt.ylabel(label)
    plt.show()

# %% [markdown]
# Through the visualization, the quality is between 3 and 9,
# so I will categorize:
# 3-5 as low quality(low),
# 6-7 as middle quality(mid),
# 8-9 as high quality(high)

# %%
bins = [0, 5.5, 7.5, 10]
labels = [0, 1, 2]
data['quality'] = pd.cut(data['quality'], bins=bins, labels=labels)

# %%
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4       0
# 1      9.8       0
# 2      9.8       0
# 3      9.8       1
# 4      9.4       0

# %% [markdown]
# # Split Data to Dependent and Independent Variables

# %%
# independent
X = np.array(data.drop('quality', axis=1))
print(X)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]

# %%
#dependent
Y = np.array(data.iloc[:,-1]).reshape((data.shape[0],1))
print(Y)
# Out:
# [[0]
#  [0]
#  [0]
#  ...
#  [1]
#  [0]
#  [1]]

# %%
model = LinearRegressor()

# %%
model.fit(X,Y)

# %%
data.index = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1000/2766620923.py in <module>
# ----> 1 data.index = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 1599 elements, new values have 12 elements

# %%
model.coef_table[:-1]
# Out:
#     Coefficients  Standard Errors  t values      p values
# 0       7.663025        14.193401  0.539901  5.893414e-01
# 1       0.018661         0.017377  1.073915  2.830240e-01
# 2      -0.548181         0.081098 -6.759485  1.939293e-11
# 3      -0.154798         0.098560 -1.570597  1.164757e-01
# 4       0.008009         0.010046  0.797214  4.254459e-01
# 5      -0.922925         0.280782 -3.286981  1.034799e-03
# 6       0.004456         0.001454  3.064570  2.216560e-03
# 7      -0.003246         0.000488 -6.652516  3.954126e-11
# 8      -8.497988        14.487069 -0.586591  5.575617e-01
# 9      -0.133681         0.128307 -1.041878  2.976269e-01
# 10      0.553347         0.076569  7.226815  7.651657e-13

# %%
model.predict(X)
# Out:
# array([[0.23914943],
#        [0.2719275 ],
#        [0.30597517],
#        ...,
#        [0.76963073],
#        [0.51453478],
#        [0.74057992]])

# %%
plt.show(X.all)
